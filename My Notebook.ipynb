# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **May Htet Htet Hlaing**
# Student

# %% [markdown]
# _I am interested in data science because I would like to explore data in various ways and draw insight from it for business needs_

# %% [markdown]
# ### The code below show the input is even or odd

# %%
def even(n):
    return (True if n/2==0 else False)
    
even(343)
# Out:
# False

# %% [markdown]
# ![image of a cat](https://upload.wikimedia.org/wikipedia/commons/thumb/1/15/Cat_August_2010-4.jpg/2560px-Cat_August_2010-4.jpg)

# %% [markdown]
# >In ancient times cats were worshipped as gods; they have not forgotten this. – **Terry Pratchett**

# %% [markdown]
# * item one
# * item two
# * item three
# * item four
